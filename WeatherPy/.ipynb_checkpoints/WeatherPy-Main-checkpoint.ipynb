# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn import datasets

# Import API key
from api_keys import weather_api_key
# import citipy
from citipy import citipy

# from api_keys import api_key

# output file (CSV)
# output_file = "output_data/cities.csv"

# range of latitues and Longitudes for random
lat_range = (-90, 90)
long_range = (-180, 180)
# create random latitudes and Longitude: change size to only 25 for testing
random_lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
random_longs = np.random.uniform(long_range[0], long_range[1], size=2000)
# zip the list together
zipped_lat_longs = zip(random_lats, random_longs)
lats_longs_list = list(zipped_lat_longs)

# %%
# for testing generate one city name
lat_long = lats_longs_list[0]

citipy.nearest_city(lat_long[0], lat_long[1]).city_name
# Out:
# 'cape town'

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('Start of Records')
print('------------------------')

# # generate emply list for cities
cities = []
# find nearest city from each lat and long
for lat_long in lats_longs_list:
    city_name = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
# if city is unique then added it to the cities list
    if city_name not in cities:
        cities.append(city_name)
# count number of citiies
# len(cities)


# create the url to call for API
base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# create list to hold all the required items:
city_name_list = []
country_list = []
lat_list = []
long_list = []
temp = []
max_temp = []
humid = []
clouds = []
wind = []

# initiate counter for city number
number = 1
# loop thru the list of cities and permorm for data on each.
for city_name in cities:
    try:
        response = requests.get(city_url + city_name).json()
        city_name_list.append(response['name'])
        lat_list.append(response['coord']['lat'])
        long_list.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        print(f"Processing Record {number} of set {len(cities)} | {city_name}")
        number = number + 1
    
#     except KeyError:
    except:
        print(f"City not found")
    continue
#         print(f"City not found {number} of {len(cities)}. | Skipping {city_name}")
#         number = number + 1

print('End of Records')
print('------------------------')
# Out:
# Start of Records
# ------------------------
# Processing Record 1 of set 769 | cape town
# Processing Record 2 of set 769 | rikitea
# Processing Record 3 of set 769 | albany
# Processing Record 4 of set 769 | ushuaia
# Processing Record 5 of set 769 | micheweni
# Processing Record 6 of set 769 | salinas
# Processing Record 7 of set 769 | east london
# Processing Record 8 of set 769 | busselton
# City not found
# Processing Record 9 of set 769 | vanimo
# Processing Record 10 of set 769 | merauke
# Processing Record 11 of set 769 | mataura
# City not found
# Processing Record 12 of set 769 | fairbanks
# Processing Record 13 of set 769 | marystown
# Processing Record 14 of set 769 | sahuaripa
# Processing Record 15 of set 769 | qaqortoq
# Processing Record 16 of set 769 | jamestown
# Processing Record 17 of set 769 | mahebourg
# Processing Record 18 of set 769 | victoria
# Processing Record 19 of set 769 | yerbogachen
# Processing Record 20 of set 769 | hobart
# Processing Record 21 of set 769 | hilo
# Processing Record 22 of set 769 | lodeynoye pole
# Processing Record 23 of set 769 | nanortalik
# Processing Record 24 of set 769 | bredasdorp
# City not found
# Processing Record 25 of set 769 | kapaa
# Processing Record 26 of set 769 | beloha
# Processing Record 27 of set 769 | edd
# Processing Record 28 of set 769 | vaini
# Processing Record 29 of set 769 | pisco
# City not found
# Processing Record 30 of set 769 | punta arenas
# Processing Record 31 of set 769 | bluff
# Processing Record 32 of set 769 | ayagoz
# Processing Record 33 of set 769 | bengkulu
# Processing Record 34 of set 769 | lebu
# Processing Record 35 of set 769 | kuala pilah
# Processing Record 36 of set 769 | hermanus
# Processing Record 37 of set 769 | maiduguri
# Processing Record 38 of set 769 | nikel
# Processing Record 39 of set 769 | churapcha
# Processing Record 40 of set 769 | saint-philippe
# Processing Record 41 of set 769 | yulara
# Processing Record 42 of set 769 | carnarvon
# Processing Record 43 of set 769 | norman wells
# Processing Record 44 of set 769 | bubaque
# Processing Record 45 of set 769 | glenwood springs
# Processing Record 46 of set 769 | magna
# Processing Record 47 of set 769 | newport
# Processing Record 48 of set 769 | kruisfontein
# Processing Record 49 of set 769 | ilulissat
# Processing Record 50 of set 769 | samarai
# Processing Record 51 of set 769 | dikson
# Processing Record 52 of set 769 | port elizabeth
# Processing Record 53 of set 769 | castro
# Processing Record 54 of set 769 | lincoln
# Processing Record 55 of set 769 | yellowknife
# City not found
# Processing Record 56 of set 769 | ossora
# Processing Record 57 of set 769 | neiafu
# Processing Record 58 of set 769 | hithadhoo
# City not found
# Processing Record 59 of set 769 | mar del plata
# Processing Record 60 of set 769 | shuangcheng
# Processing Record 61 of set 769 | chuy
# Processing Record 62 of set 769 | dabakala
# Processing Record 63 of set 769 | kalmunai
# Processing Record 64 of set 769 | pervomayskoye
# Processing Record 65 of set 769 | port blair
# Processing Record 66 of set 769 | mahajanga
# Processing Record 67 of set 769 | avarua
# City not found
# Processing Record 68 of set 769 | namatanai
# Processing Record 69 of set 769 | khatanga
# Processing Record 70 of set 769 | nizwa
# Processing Record 71 of set 769 | arraial do cabo
# City not found
# Processing Record 72 of set 769 | luderitz
# City not found
# City not found
# Processing Record 73 of set 769 | chokurdakh
# Processing Record 74 of set 769 | bonthe
# Processing Record 75 of set 769 | singapore
# Processing Record 76 of set 769 | coffs harbour
# Processing Record 77 of set 769 | qaanaaq
# Processing Record 78 of set 769 | tuatapere
# City not found
# Processing Record 79 of set 769 | lorengau
# Processing Record 80 of set 769 | sydney mines
# Processing Record 81 of set 769 | miyako
# Processing Record 82 of set 769 | clyde river
# Processing Record 83 of set 769 | esmeralda
# Processing Record 84 of set 769 | atuona
# Processing Record 85 of set 769 | kupang
# Processing Record 86 of set 769 | thomasville
# Processing Record 87 of set 769 | aklavik
# Processing Record 88 of set 769 | shimoda
# Processing Record 89 of set 769 | bandarbeyla
# Processing Record 90 of set 769 | cidreira
# Processing Record 91 of set 769 | cockburn town
# Processing Record 92 of set 769 | hambantota
# City not found
# Processing Record 93 of set 769 | aktau
# Processing Record 94 of set 769 | sao joao da barra
# Processing Record 95 of set 769 | auki
# Processing Record 96 of set 769 | amboasary
# Processing Record 97 of set 769 | kodiak
# Processing Record 98 of set 769 | roald
# Processing Record 99 of set 769 | puerto ayora
# Processing Record 100 of set 769 | marsaxlokk
# Processing Record 101 of set 769 | porto novo
# Processing Record 102 of set 769 | barrow
# Processing Record 103 of set 769 | brae
# Processing Record 104 of set 769 | dunedin
# Processing Record 105 of set 769 | halifax
# Processing Record 106 of set 769 | talnakh
# Processing Record 107 of set 769 | sungaipenuh
# Processing Record 108 of set 769 | valley city
# Processing Record 109 of set 769 | ixtapa
# Processing Record 110 of set 769 | hasaki
# Processing Record 111 of set 769 | jiuquan
# Processing Record 112 of set 769 | bethel
# Processing Record 113 of set 769 | kavaratti
# Processing Record 114 of set 769 | hay river
# Processing Record 115 of set 769 | aljezur
# Processing Record 116 of set 769 | faanui
# Processing Record 117 of set 769 | vitim
# Processing Record 118 of set 769 | rock sound
# Processing Record 119 of set 769 | seoul
# Processing Record 120 of set 769 | coahuayana
# Processing Record 121 of set 769 | blagoyevo
# Processing Record 122 of set 769 | port-gentil
# Processing Record 123 of set 769 | provideniya
# Processing Record 124 of set 769 | saint anthony
# Processing Record 125 of set 769 | torbay
# City not found
# Processing Record 126 of set 769 | wyszkow
# Processing Record 127 of set 769 | ambunti
# Processing Record 128 of set 769 | hamilton
# City not found
# Processing Record 129 of set 769 | san policarpo
# Processing Record 130 of set 769 | marsh harbour
# Processing Record 131 of set 769 | jalu
# Processing Record 132 of set 769 | surgut
# City not found
# Processing Record 133 of set 769 | cascais
# Processing Record 134 of set 769 | jacobabad
# Processing Record 135 of set 769 | souillac
# City not found
# Processing Record 136 of set 769 | rawson
# Processing Record 137 of set 769 | villarrobledo
# Processing Record 138 of set 769 | vao
# Processing Record 139 of set 769 | arlit
# City not found
# Processing Record 140 of set 769 | narsaq
# Processing Record 141 of set 769 | sambava
# Processing Record 142 of set 769 | gasa
# Processing Record 143 of set 769 | ribeira grande
# Processing Record 144 of set 769 | bryan
# Processing Record 145 of set 769 | matay
# Processing Record 146 of set 769 | alta floresta
# Processing Record 147 of set 769 | thompson
# Processing Record 148 of set 769 | new norfolk
# Processing Record 149 of set 769 | saint-pierre
# Processing Record 150 of set 769 | iqaluit
# Processing Record 151 of set 769 | garden city
# Processing Record 152 of set 769 | mwinilunga
# Processing Record 153 of set 769 | tiksi
# Processing Record 154 of set 769 | nikolskoye
# Processing Record 155 of set 769 | gao
# Processing Record 156 of set 769 | kapit
# Processing Record 157 of set 769 | severo-kurilsk
# Processing Record 158 of set 769 | taoudenni
# Processing Record 159 of set 769 | saint george
# City not found
# Processing Record 160 of set 769 | upernavik
# Processing Record 161 of set 769 | samagaltay
# Processing Record 162 of set 769 | ponta do sol
# Processing Record 163 of set 769 | arenzano
# Processing Record 164 of set 769 | touros
# City not found
# Processing Record 165 of set 769 | richards bay
# Processing Record 166 of set 769 | ewa beach
# Processing Record 167 of set 769 | kaitangata
# Processing Record 168 of set 769 | adrar
# Processing Record 169 of set 769 | tuktoyaktuk
# Processing Record 170 of set 769 | vardo
# Processing Record 171 of set 769 | itarema
# Processing Record 172 of set 769 | tombouctou
# Processing Record 173 of set 769 | champerico
# Processing Record 174 of set 769 | agadez
# Processing Record 175 of set 769 | farafangana
# Processing Record 176 of set 769 | moron
# Processing Record 177 of set 769 | misratah
# Processing Record 178 of set 769 | nome
# Processing Record 179 of set 769 | andenes
# Processing Record 180 of set 769 | tual
# City not found
# Processing Record 181 of set 769 | qurayyat
# Processing Record 182 of set 769 | lubyany
# City not found
# Processing Record 183 of set 769 | longyearbyen
# City not found
# City not found
# Processing Record 184 of set 769 | karratha
# Processing Record 185 of set 769 | phuket
# Processing Record 186 of set 769 | sabzevar
# Processing Record 187 of set 769 | meiganga
# Processing Record 188 of set 769 | makakilo city
# Processing Record 189 of set 769 | airai
# Processing Record 190 of set 769 | najran
# Processing Record 191 of set 769 | huarmey
# Processing Record 192 of set 769 | pisz
# Processing Record 193 of set 769 | klaksvik
# Processing Record 194 of set 769 | constitucion
# Processing Record 195 of set 769 | karaidel
# Processing Record 196 of set 769 | ambon
# Processing Record 197 of set 769 | kidal
# Processing Record 198 of set 769 | fortuna
# Processing Record 199 of set 769 | deputatskiy
# Processing Record 200 of set 769 | kaspiyskiy
# Processing Record 201 of set 769 | berlevag
# Processing Record 202 of set 769 | saldanha
# Processing Record 203 of set 769 | bambous virieux
# City not found
# Processing Record 204 of set 769 | gulu
# Processing Record 205 of set 769 | luanda
# Processing Record 206 of set 769 | ikom
# Processing Record 207 of set 769 | santa isabel do rio negro
# Processing Record 208 of set 769 | berdigestyakh
# Processing Record 209 of set 769 | norfolk
# Processing Record 210 of set 769 | tasiilaq
# Processing Record 211 of set 769 | palanpur
# City not found
# Processing Record 212 of set 769 | kununurra
# Processing Record 213 of set 769 | urengoy
# Processing Record 214 of set 769 | yeppoon
# Processing Record 215 of set 769 | independencia
# Processing Record 216 of set 769 | verkhoyansk
# Processing Record 217 of set 769 | lewiston
# City not found
# Processing Record 218 of set 769 | aksarka
# Processing Record 219 of set 769 | korla
# Processing Record 220 of set 769 | waipawa
# Processing Record 221 of set 769 | mount gambier
# Processing Record 222 of set 769 | senneterre
# Processing Record 223 of set 769 | lasa
# Processing Record 224 of set 769 | isangel
# Processing Record 225 of set 769 | whitehorse
# Processing Record 226 of set 769 | margate
# Processing Record 227 of set 769 | salalah
# Processing Record 228 of set 769 | guanhaes
# Processing Record 229 of set 769 | lavrentiya
# City not found
# Processing Record 230 of set 769 | henties bay
# Processing Record 231 of set 769 | nemuro
# Processing Record 232 of set 769 | petropavlovsk-kamchatskiy
# City not found
# Processing Record 233 of set 769 | the valley
# Processing Record 234 of set 769 | bathsheba
# Processing Record 235 of set 769 | millau
# Processing Record 236 of set 769 | weihai
# Processing Record 237 of set 769 | mujiayingzi
# Processing Record 238 of set 769 | vestmannaeyjar
# Processing Record 239 of set 769 | namibe
# Processing Record 240 of set 769 | marienburg
# Processing Record 241 of set 769 | cabo san lucas
# Processing Record 242 of set 769 | walvis bay
# Processing Record 243 of set 769 | zambezi
# Processing Record 244 of set 769 | port alfred
# Processing Record 245 of set 769 | terrace
# Processing Record 246 of set 769 | ostrovnoy
# Processing Record 247 of set 769 | saint-leu
# Processing Record 248 of set 769 | college
# Processing Record 249 of set 769 | port lincoln
# Processing Record 250 of set 769 | pointe-noire
# Processing Record 251 of set 769 | north bend
# Processing Record 252 of set 769 | pandan
# Processing Record 253 of set 769 | almoloya
# Processing Record 254 of set 769 | xining
# Processing Record 255 of set 769 | trebaseleghe
# Processing Record 256 of set 769 | esperance
# Processing Record 257 of set 769 | cherskiy
# Processing Record 258 of set 769 | chapais
# Processing Record 259 of set 769 | codrington
# City not found
# Processing Record 260 of set 769 | sibolga
# Processing Record 261 of set 769 | los llanos de aridane
# Processing Record 262 of set 769 | antofagasta
# Processing Record 263 of set 769 | amga
# Processing Record 264 of set 769 | alice springs
# Processing Record 265 of set 769 | ust-maya
# Processing Record 266 of set 769 | avera
# Processing Record 267 of set 769 | kudahuvadhoo
# City not found
# Processing Record 268 of set 769 | katsuura
# Processing Record 269 of set 769 | heihe
# Processing Record 270 of set 769 | inuvik
# Processing Record 271 of set 769 | nilo
# Processing Record 272 of set 769 | kahului
# City not found
# Processing Record 273 of set 769 | fort nelson
# Processing Record 274 of set 769 | la tuque
# Processing Record 275 of set 769 | kamenka
# Processing Record 276 of set 769 | chinhoyi
# Processing Record 277 of set 769 | sao filipe
# Processing Record 278 of set 769 | newcastle
# Processing Record 279 of set 769 | basco
# City not found
# Processing Record 280 of set 769 | kandrian
# Processing Record 281 of set 769 | zalantun
# Processing Record 282 of set 769 | uray
# Processing Record 283 of set 769 | dingle
# Processing Record 284 of set 769 | asbestovskiy
# City not found
# Processing Record 285 of set 769 | cotacachi
# Processing Record 286 of set 769 | delijan
# Processing Record 287 of set 769 | krasnyy yar
# Processing Record 288 of set 769 | georgetown
# Processing Record 289 of set 769 | lamar
# Processing Record 290 of set 769 | broken hill
# Processing Record 291 of set 769 | bitung
# Processing Record 292 of set 769 | sorong
# Processing Record 293 of set 769 | lake havasu city
# City not found
# Processing Record 294 of set 769 | rwamagana
# Processing Record 295 of set 769 | arti
# Processing Record 296 of set 769 | arona
# Processing Record 297 of set 769 | totma
# Processing Record 298 of set 769 | oriximina
# Processing Record 299 of set 769 | abeche
# Processing Record 300 of set 769 | durban
# Processing Record 301 of set 769 | los chiles
# Processing Record 302 of set 769 | elmadag
# Processing Record 303 of set 769 | butaritari
# Processing Record 304 of set 769 | krasnyy chikoy
# Processing Record 305 of set 769 | guerrero negro
# Processing Record 306 of set 769 | solano
# Processing Record 307 of set 769 | nicoya
# Processing Record 308 of set 769 | erdaojiang
# Processing Record 309 of set 769 | lhokseumawe
# Processing Record 310 of set 769 | borgarnes
# Processing Record 311 of set 769 | benjamin aceval
# City not found
# Processing Record 312 of set 769 | edremit
# Processing Record 313 of set 769 | zhangye
# Processing Record 314 of set 769 | bairiki
# Processing Record 315 of set 769 | banda aceh
# Processing Record 316 of set 769 | sarahan
# Processing Record 317 of set 769 | fruitville
# Processing Record 318 of set 769 | tra vinh
# City not found
# Processing Record 319 of set 769 | chumikan
# Processing Record 320 of set 769 | odweyne
# Processing Record 321 of set 769 | farah
# Processing Record 322 of set 769 | burnie
# Processing Record 323 of set 769 | naze
# Processing Record 324 of set 769 | taree
# Processing Record 325 of set 769 | banjar
# Processing Record 326 of set 769 | samfya
# Processing Record 327 of set 769 | lagoa
# Processing Record 328 of set 769 | sistranda
# Processing Record 329 of set 769 | atar
# Processing Record 330 of set 769 | bonavista
# Processing Record 331 of set 769 | sitka
# Processing Record 332 of set 769 | saint-augustin
# Processing Record 333 of set 769 | namtsy
# Processing Record 334 of set 769 | gibara
# Processing Record 335 of set 769 | saint andrews
# City not found
# City not found
# Processing Record 336 of set 769 | ercis
# City not found
# Processing Record 337 of set 769 | santa marinella
# Processing Record 338 of set 769 | kulhudhuffushi
# Processing Record 339 of set 769 | kutum
# Processing Record 340 of set 769 | acajutla
# Processing Record 341 of set 769 | mahon
# Processing Record 342 of set 769 | belmonte
# Processing Record 343 of set 769 | rudbar
# Processing Record 344 of set 769 | vilyuysk
# Processing Record 345 of set 769 | vychegodskiy
# Processing Record 346 of set 769 | copiapo
# Processing Record 347 of set 769 | olafsvik
# Processing Record 348 of set 769 | yar-sale
# Processing Record 349 of set 769 | vila franca do campo
# Processing Record 350 of set 769 | chicla
# Processing Record 351 of set 769 | inverell
# Processing Record 352 of set 769 | khasan
# Processing Record 353 of set 769 | yermakovskoye
# Processing Record 354 of set 769 | alofi
# City not found
# Processing Record 355 of set 769 | gibsons
# Processing Record 356 of set 769 | atlantic beach
# Processing Record 357 of set 769 | viedma
# Processing Record 358 of set 769 | mission
# Processing Record 359 of set 769 | lufilufi
# Processing Record 360 of set 769 | sidney
# Processing Record 361 of set 769 | vadso
# Processing Record 362 of set 769 | trapani
# Processing Record 363 of set 769 | contamana
# Processing Record 364 of set 769 | grindavik
# Processing Record 365 of set 769 | olive branch
# Processing Record 366 of set 769 | carutapera
# Processing Record 367 of set 769 | santa cruz
# Processing Record 368 of set 769 | rocha
# City not found
# Processing Record 369 of set 769 | khorramshahr
# Processing Record 370 of set 769 | mahanje
# Processing Record 371 of set 769 | flin flon
# Processing Record 372 of set 769 | mangaratiba
# Processing Record 373 of set 769 | barcelos
# Processing Record 374 of set 769 | benjamin constant
# Processing Record 375 of set 769 | ust-koksa
# Processing Record 376 of set 769 | puerto carreno
# Processing Record 377 of set 769 | baykit
# Processing Record 378 of set 769 | liverpool
# Processing Record 379 of set 769 | portland
# Processing Record 380 of set 769 | karpinsk
# City not found
# Processing Record 381 of set 769 | mikhaylovka
# Processing Record 382 of set 769 | udachnyy
# Processing Record 383 of set 769 | borovoy
# Processing Record 384 of set 769 | shenjiamen
# Processing Record 385 of set 769 | hearst
# Processing Record 386 of set 769 | novaci
# City not found
# Processing Record 387 of set 769 | shatrovo
# Processing Record 388 of set 769 | haldibari
# Processing Record 389 of set 769 | pevek
# Processing Record 390 of set 769 | meulaboh
# Processing Record 391 of set 769 | patiya
# Processing Record 392 of set 769 | coeneo
# Processing Record 393 of set 769 | nyurba
# Processing Record 394 of set 769 | skelleftea
# Processing Record 395 of set 769 | padang
# Processing Record 396 of set 769 | las vegas
# Processing Record 397 of set 769 | mbini
# Processing Record 398 of set 769 | antalaha
# Processing Record 399 of set 769 | alyangula
# Processing Record 400 of set 769 | wanaka
# Processing Record 401 of set 769 | xuddur
# Processing Record 402 of set 769 | sioux lookout
# Processing Record 403 of set 769 | fayaoue
# Processing Record 404 of set 769 | plettenberg bay
# Processing Record 405 of set 769 | stanghelle
# Processing Record 406 of set 769 | jeremie
# Processing Record 407 of set 769 | muzhi
# Processing Record 408 of set 769 | mocuba
# Processing Record 409 of set 769 | itoman
# Processing Record 410 of set 769 | aksu
# Processing Record 411 of set 769 | tautira
# City not found
# Processing Record 412 of set 769 | nago
# Processing Record 413 of set 769 | kavieng
# City not found
# Processing Record 414 of set 769 | zonguldak
# Processing Record 415 of set 769 | baghdad
# Processing Record 416 of set 769 | izyaslav
# Processing Record 417 of set 769 | vavuniya
# Processing Record 418 of set 769 | san juan
# City not found
# Processing Record 419 of set 769 | la paz
# Processing Record 420 of set 769 | hami
# Processing Record 421 of set 769 | pontes e lacerda
# Processing Record 422 of set 769 | nanakuli
# Processing Record 423 of set 769 | duncan
# Processing Record 424 of set 769 | glendive
# Processing Record 425 of set 769 | bud
# Processing Record 426 of set 769 | campbell river
# Processing Record 427 of set 769 | nabire
# Processing Record 428 of set 769 | mattru
# Processing Record 429 of set 769 | george town
# Processing Record 430 of set 769 | comal
# City not found
# Processing Record 431 of set 769 | santiago del estero
# Processing Record 432 of set 769 | karlstad
# Processing Record 433 of set 769 | sola
# Processing Record 434 of set 769 | kabalo
# Processing Record 435 of set 769 | kargasok
# Processing Record 436 of set 769 | simav
# Processing Record 437 of set 769 | daru
# Processing Record 438 of set 769 | elbrus
# Processing Record 439 of set 769 | villablino
# Processing Record 440 of set 769 | lata
# Processing Record 441 of set 769 | menongue
# Processing Record 442 of set 769 | ahipara
# Processing Record 443 of set 769 | tanout
# Processing Record 444 of set 769 | komsomolskiy
# Processing Record 445 of set 769 | bowen
# Processing Record 446 of set 769 | srednekolymsk
# Processing Record 447 of set 769 | corinto
# Processing Record 448 of set 769 | bilibino
# Processing Record 449 of set 769 | lompoc
# Processing Record 450 of set 769 | leland
# Processing Record 451 of set 769 | buala
# Processing Record 452 of set 769 | la romana
# Processing Record 453 of set 769 | uglovskoye
# Processing Record 454 of set 769 | sun city west
# Processing Record 455 of set 769 | pokhara
# Processing Record 456 of set 769 | comodoro rivadavia
# Processing Record 457 of set 769 | koslan
# Processing Record 458 of set 769 | khandyga
# Processing Record 459 of set 769 | moussoro
# Processing Record 460 of set 769 | kaohsiung
# Processing Record 461 of set 769 | svetlaya
# Processing Record 462 of set 769 | aykhal
# Processing Record 463 of set 769 | bac lieu
# Processing Record 464 of set 769 | mercedes
# Processing Record 465 of set 769 | fare
# Processing Record 466 of set 769 | ndele
# City not found
# Processing Record 467 of set 769 | sobolevo
# Processing Record 468 of set 769 | usinsk
# Processing Record 469 of set 769 | kasongo-lunda
# Processing Record 470 of set 769 | joutseno
# Processing Record 471 of set 769 | ambam
# Processing Record 472 of set 769 | kailua
# Processing Record 473 of set 769 | gravdal
# Processing Record 474 of set 769 | vigrestad
# City not found
# Processing Record 475 of set 769 | pacific grove
# City not found
# Processing Record 476 of set 769 | kanashevo
# Processing Record 477 of set 769 | tura
# Processing Record 478 of set 769 | gamba
# Processing Record 479 of set 769 | zhigansk
# Processing Record 480 of set 769 | mancio lima
# Processing Record 481 of set 769 | morros
# Processing Record 482 of set 769 | dryden
# Processing Record 483 of set 769 | opuwo
# Processing Record 484 of set 769 | oussouye
# Processing Record 485 of set 769 | plouzane
# Processing Record 486 of set 769 | dukat
# Processing Record 487 of set 769 | gayeri
# Processing Record 488 of set 769 | geraldton
# Processing Record 489 of set 769 | saskylakh
# Processing Record 490 of set 769 | waddan
# Processing Record 491 of set 769 | tilichiki
# Processing Record 492 of set 769 | along
# Processing Record 493 of set 769 | pitimbu
# Processing Record 494 of set 769 | poronaysk
# Processing Record 495 of set 769 | solms
# Processing Record 496 of set 769 | puerto baquerizo moreno
# Processing Record 497 of set 769 | saint-paul
# Processing Record 498 of set 769 | san jose
# Processing Record 499 of set 769 | ngunguru
# Processing Record 500 of set 769 | anloga
# City not found
# Processing Record 501 of set 769 | cabildo
# Processing Record 502 of set 769 | pedernales
# Processing Record 503 of set 769 | bar harbor
# Processing Record 504 of set 769 | candolim
# Processing Record 505 of set 769 | gallup
# Processing Record 506 of set 769 | beirut
# Processing Record 507 of set 769 | nuuk
# Processing Record 508 of set 769 | coihaique
# Processing Record 509 of set 769 | chambishi
# Processing Record 510 of set 769 | moose factory
# Processing Record 511 of set 769 | vanavara
# Processing Record 512 of set 769 | khorixas
# Processing Record 513 of set 769 | awash
# Processing Record 514 of set 769 | the pas
# Processing Record 515 of set 769 | radhanpur
# Processing Record 516 of set 769 | rio grande
# Processing Record 517 of set 769 | kindberg
# Processing Record 518 of set 769 | marshfield
# Processing Record 519 of set 769 | nove mesto na morave
# City not found
# Processing Record 520 of set 769 | hofn
# Processing Record 521 of set 769 | belaya gora
# Processing Record 522 of set 769 | nokaneng
# Processing Record 523 of set 769 | coihueco
# Processing Record 524 of set 769 | ust-omchug
# Processing Record 525 of set 769 | togur
# Processing Record 526 of set 769 | te anau
# Processing Record 527 of set 769 | vagay
# Processing Record 528 of set 769 | laguna
# Processing Record 529 of set 769 | tessalit
# Processing Record 530 of set 769 | nouadhibou
# Processing Record 531 of set 769 | coracora
# Processing Record 532 of set 769 | mathbaria
# Processing Record 533 of set 769 | mastung
# Processing Record 534 of set 769 | atasu
# Processing Record 535 of set 769 | puerto escondido
# Processing Record 536 of set 769 | fonte boa
# Processing Record 537 of set 769 | praya
# Processing Record 538 of set 769 | likasi
# Processing Record 539 of set 769 | qeshm
# Processing Record 540 of set 769 | parabel
# Processing Record 541 of set 769 | nisia floresta
# City not found
# Processing Record 542 of set 769 | canutama
# Processing Record 543 of set 769 | harrismith
# Processing Record 544 of set 769 | sabha
# Processing Record 545 of set 769 | bilma
# City not found
# Processing Record 546 of set 769 | ola
# Processing Record 547 of set 769 | lanzhou
# Processing Record 548 of set 769 | tahoua
# Processing Record 549 of set 769 | mapiripan
# Processing Record 550 of set 769 | shiyan
# Processing Record 551 of set 769 | shar
# Processing Record 552 of set 769 | umm lajj
# Processing Record 553 of set 769 | dubbo
# Processing Record 554 of set 769 | la suiza
# Processing Record 555 of set 769 | tias
# Processing Record 556 of set 769 | antsirabe
# Processing Record 557 of set 769 | gobabis
# Processing Record 558 of set 769 | okha
# Processing Record 559 of set 769 | leningradskiy
# Processing Record 560 of set 769 | coquimbo
# Processing Record 561 of set 769 | pierre
# Processing Record 562 of set 769 | solhan
# Processing Record 563 of set 769 | mabua
# Processing Record 564 of set 769 | ranong
# Processing Record 565 of set 769 | bom jesus
# Processing Record 566 of set 769 | paamiut
# Processing Record 567 of set 769 | birin
# Processing Record 568 of set 769 | chimbote
# Processing Record 569 of set 769 | bousse
# Processing Record 570 of set 769 | pringsewu
# Processing Record 571 of set 769 | rundu
# Processing Record 572 of set 769 | uribia
# Processing Record 573 of set 769 | svetlyy yar
# Processing Record 574 of set 769 | marshall
# Processing Record 575 of set 769 | urubicha
# Processing Record 576 of set 769 | gat
# Processing Record 577 of set 769 | wattegama
# Processing Record 578 of set 769 | irondequoit
# Processing Record 579 of set 769 | puri
# Processing Record 580 of set 769 | caravelas
# Processing Record 581 of set 769 | high level
# Processing Record 582 of set 769 | mount pleasant
# Processing Record 583 of set 769 | pingliang
# Processing Record 584 of set 769 | mayo
# Processing Record 585 of set 769 | honiara
# Processing Record 586 of set 769 | angoche
# City not found
# Processing Record 587 of set 769 | bulolo
# Processing Record 588 of set 769 | pangnirtung
# Processing Record 589 of set 769 | muroto
# Processing Record 590 of set 769 | cayenne
# Processing Record 591 of set 769 | mitsamiouli
# Processing Record 592 of set 769 | sao gabriel da cachoeira
# Processing Record 593 of set 769 | carinhanha
# Processing Record 594 of set 769 | bagdarin
# Processing Record 595 of set 769 | humaita
# Processing Record 596 of set 769 | ginda
# Processing Record 597 of set 769 | tevaitoa
# City not found
# Processing Record 598 of set 769 | sakakah
# Processing Record 599 of set 769 | keetmanshoop
# Processing Record 600 of set 769 | tazovskiy
# Processing Record 601 of set 769 | tsabong
# Processing Record 602 of set 769 | puntarenas
# Processing Record 603 of set 769 | worland
# Processing Record 604 of set 769 | vila velha
# Processing Record 605 of set 769 | kisangani
# Processing Record 606 of set 769 | poum
# Processing Record 607 of set 769 | lucea
# Processing Record 608 of set 769 | ban nahin
# Processing Record 609 of set 769 | tabuk
# Processing Record 610 of set 769 | kamenice
# Processing Record 611 of set 769 | guane
# Processing Record 612 of set 769 | puteyets
# Processing Record 613 of set 769 | inhambane
# City not found
# Processing Record 614 of set 769 | lac du bonnet
# Processing Record 615 of set 769 | kainantu
# Processing Record 616 of set 769 | cochabamba
# Processing Record 617 of set 769 | camacha
# City not found
# Processing Record 618 of set 769 | horodnytsya
# Processing Record 619 of set 769 | majene
# Processing Record 620 of set 769 | nhulunbuy
# Processing Record 621 of set 769 | stanislav
# Processing Record 622 of set 769 | killybegs
# Processing Record 623 of set 769 | gizo
# Processing Record 624 of set 769 | nizip
# Processing Record 625 of set 769 | areia branca
# Processing Record 626 of set 769 | zlobin
# Processing Record 627 of set 769 | placido de castro
# Processing Record 628 of set 769 | sabang
# Processing Record 629 of set 769 | bangangte
# Processing Record 630 of set 769 | santa isabel
# Processing Record 631 of set 769 | veydelevka
# Processing Record 632 of set 769 | benin
# Processing Record 633 of set 769 | kushima
# Processing Record 634 of set 769 | itupiranga
# Processing Record 635 of set 769 | batagay-alyta
# Processing Record 636 of set 769 | ajdabiya
# Processing Record 637 of set 769 | havelock
# Processing Record 638 of set 769 | suzhou
# Processing Record 639 of set 769 | havre-saint-pierre
# Processing Record 640 of set 769 | dzilam gonzalez
# City not found
# Processing Record 641 of set 769 | lafayette
# Processing Record 642 of set 769 | murgab
# Processing Record 643 of set 769 | bograd
# Processing Record 644 of set 769 | mount isa
# Processing Record 645 of set 769 | superior
# Processing Record 646 of set 769 | sokolo
# Processing Record 647 of set 769 | kokopo
# Processing Record 648 of set 769 | donskoye
# Processing Record 649 of set 769 | businga
# Processing Record 650 of set 769 | naifaru
# Processing Record 651 of set 769 | ancud
# Processing Record 652 of set 769 | da nang
# Processing Record 653 of set 769 | kirakira
# Processing Record 654 of set 769 | westport
# Processing Record 655 of set 769 | liuhe
# Processing Record 656 of set 769 | mogocha
# Processing Record 657 of set 769 | quatre cocos
# Processing Record 658 of set 769 | puerto cabezas
# Processing Record 659 of set 769 | tolaga bay
# Processing Record 660 of set 769 | calabozo
# Processing Record 661 of set 769 | apollonia
# Processing Record 662 of set 769 | aginskoye
# Processing Record 663 of set 769 | joshimath
# City not found
# Processing Record 664 of set 769 | puerto leguizamo
# Processing Record 665 of set 769 | gayny
# Processing Record 666 of set 769 | erenhot
# Processing Record 667 of set 769 | hatillo
# Processing Record 668 of set 769 | golspie
# City not found
# Processing Record 669 of set 769 | malinovoye ozero
# Processing Record 670 of set 769 | sosnovo-ozerskoye
# City not found
# Processing Record 671 of set 769 | san quintin
# Processing Record 672 of set 769 | syedove
# Processing Record 673 of set 769 | ambanja
# Processing Record 674 of set 769 | naron
# Processing Record 675 of set 769 | busko-zdroj
# Processing Record 676 of set 769 | san jeronimo
# Processing Record 677 of set 769 | japura
# Processing Record 678 of set 769 | arkadelphia
# Processing Record 679 of set 769 | prainha
# Processing Record 680 of set 769 | atambua
# Processing Record 681 of set 769 | sarzedo
# Processing Record 682 of set 769 | broome
# Processing Record 683 of set 769 | egvekinot
# Processing Record 684 of set 769 | sao jose da coroa grande
# Processing Record 685 of set 769 | nampa
# Processing Record 686 of set 769 | hualmay
# Processing Record 687 of set 769 | evanston
# Processing Record 688 of set 769 | fukuma
# Processing Record 689 of set 769 | belem de sao francisco
# Processing Record 690 of set 769 | natchez
# Processing Record 691 of set 769 | tashla
# Processing Record 692 of set 769 | araceli
# Processing Record 693 of set 769 | nakhon si thammarat
# Processing Record 694 of set 769 | samoded
# City not found
# Processing Record 695 of set 769 | pangai
# Processing Record 696 of set 769 | palmer
# Processing Record 697 of set 769 | erzin
# Processing Record 698 of set 769 | aswan
# Processing Record 699 of set 769 | nanlong
# Processing Record 700 of set 769 | karonga
# Processing Record 701 of set 769 | kintampo
# City not found
# Processing Record 702 of set 769 | camana
# Processing Record 703 of set 769 | sirur
# Processing Record 704 of set 769 | nova borova
# Processing Record 705 of set 769 | hiriyur
# End of Records
# ------------------------

# %%
# create DataFrame with the items:
city_data_df = pd.DataFrame({'City': city_name_list,
                             'Latitude': lat_list,
                             'Longtude': long_list,
                             'Temperature': temp,
                             'Max Temperature': max_temp,
                             'Humidity': humid,
                             'Clouds': clouds,
                             'Wind Speed': wind
    
})
city_data_df
# Out:
#             City  Latitude  Longtude  Temperature  Max Temperature  Humidity  \
# 0      Cape Town  -33.9258   18.4232        46.87            48.61        73
# 1        Rikitea  -23.1203 -134.9692        73.11            73.11        57
# 2         Albany   42.6001  -73.9662        70.95            77.31        72
# 3        Ushuaia  -54.8000  -68.3000        33.46            33.46        86
# 4      Micheweni   -4.9667   39.8333        76.21            76.21        80
# ..           ...       ...       ...          ...              ...       ...
# 700     Kintampo    8.0563   -1.7306        72.59            72.59        87
# 701       Camaná  -16.6228  -72.7111        63.41            63.41        78
# 702        Sirūr   18.8333   74.3833        72.99            72.99        93
# 703  Nova Borova   50.6930   28.6345        60.35            60.35        82
# 704      Hiriyūr   13.9456   76.6192        72.05            72.05        83
#
#      Clouds  Wind Speed
# 0        40        3.00
# 1        35       15.26
# 2        59        8.99
# 3        75        5.75
# 4         2       12.64
# ..      ...         ...
# 700      44        4.61
# 701       3        4.38
# 702     100       18.28
# 703      87        9.31
# 704     100       18.21
#
# [705 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# save the DataFrame as csv
city_data_df.to_csv("weather_data.csv", index = False)

# %%
# check the DataFrame for cities that have Humidity above 100
# Skip this step if there are no cities that have humidity > 100%.
humidity_100 = city_data_df[city_data_df["Humidity"]>100]
humidity_100
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longtude, Temperature, Max Temperature, Humidity, Clouds, Wind Speed]
# Index: []

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# plot Latitude vs. Temp plot - of course we will use scatter plot
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'], facecolor = "steelblue", edgecolor = "black")
plt.title("Temperature in World Cities")
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.show()
# save the plotted figure as .pngs
plt.savefig("City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# plot Latitude vs. Humidity plot - of course we will use scatter plot
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], facecolor = "steelblue", edgecolor = "black")

plt.title("Humidity in World Cities")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.show()
# save the plotted figure as .pngs
plt.savefig("City Latitude vs Humidity (%).png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# plot Latitude vs. Cloudiness plot - of course we will use scatter plot
plt.scatter(city_data_df['Latitude'], city_data_df['Clouds'], facecolor = "steelblue", edgecolor = "black")

plt.title("Cloudiness in World Cities")
plt.ylabel('Clouds')
plt.xlabel('Latitude')
plt.show()
# save the plotted figure as .pngs
plt.savefig("City Latitude vs Cloudiness (%).png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# plot Latitude vs. Cloudiness plot - of course we will use scatter plot
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], facecolor = "steelblue", edgecolor = "black")

plt.title("Wind Speed in World Cities")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.show()
# save the plotted figure as .pngs
plt.savefig("City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# create Northern and Southern Hemisphere DF
northern_hem = city_data_df.loc[city_data_df["Latitude"] >= 0]
southern_hem = city_data_df.loc[city_data_df["Latitude"] < 0]

# %%
northern_hem
# Out:
#             City  Latitude  Longtude  Temperature  Max Temperature  Humidity  \
# 2         Albany   42.6001  -73.9662        70.95            77.31        72
# 5        Salinas   36.6777 -121.6555        67.15            92.57        64
# 11     Fairbanks   64.8378 -147.7164        71.24            72.09        50
# 12     Marystown   47.1666  -55.1483        60.40            60.40        95
# 13     Sahuaripa   29.0500 -109.2333        97.57            97.57        37
# ..           ...       ...       ...          ...              ...       ...
# 698      Nanlong   31.3533  106.0631        74.08            74.08        93
# 700     Kintampo    8.0563   -1.7306        72.59            72.59        87
# 702        Sirūr   18.8333   74.3833        72.99            72.99        93
# 703  Nova Borova   50.6930   28.6345        60.35            60.35        82
# 704      Hiriyūr   13.9456   76.6192        72.05            72.05        83
#
#      Clouds  Wind Speed
# 2        59        8.99
# 5         1       14.97
# 11       20        0.00
# 12      100        8.59
# 13        8        5.50
# ..      ...         ...
# 698      93        3.00
# 700      44        4.61
# 702     100       18.28
# 703      87        9.31
# 704     100       18.21
#
# [484 rows x 8 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the Linear regression for Northern Hemishpere
x_values = northern_hem["Latitude"]
y_values = northern_hem["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.4544370961315412
# y = -0.48x + 91.65

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the Linear regression for Southern
x_values = southern_hem["Latitude"]
y_values = southern_hem["Max Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
# set x and y labels
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.5833919421453813
# y = 0.81x + 80.48

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Northern Hemishpere
x_values = northern_hem["Latitude"]
y_values = northern_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.009746650520190081
# y = 0.1x + 67.57

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Southern Hemishpere
x_values = southern_hem["Latitude"]
y_values = southern_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.0009844498014775279
# y = -0.05x + 68.43

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Northern Hemishpere
x_values = northern_hem["Latitude"]
y_values = northern_hem["Clouds"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.002601662898677999
# y = -0.1x + 61.77

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Southern Hemishpere
x_values = southern_hem["Latitude"]
y_values = southern_hem["Clouds"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.023284282765381067
# y = -0.44x + 37.44

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Northern Hemishpere
x_values = northern_hem["Latitude"]
y_values = northern_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.014454786888828607
# y = -0.04x + 9.25

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the Linear regression for Southern Hemishpere
x_values = southern_hem["Latitude"]
y_values = southern_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolor = "steelblue", edgecolor = "black")
plt.plot(x_values,regress_values, "r-")
plt.annotate(line_eq, (6,10), fontsize=15,color="red")
# Set a title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.show()
# save the plotted figure as .pngs
plt.savefig("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.01803201662284804
# y = -0.06x + 6.76
